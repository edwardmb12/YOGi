# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /Users/ejm-b/.pyenv/versions/3.10.6/envs/YOGi/lib/python3.10/site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.19.3 in /Users/ejm-b/.pyenv/versions/3.10.6/envs/YOGi/lib/python3.10/site-packages (from opencv-python) (1.24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install imutils
# Out:
# Requirement already satisfied: imutils in /Users/ejm-b/.pyenv/versions/3.10.6/envs/YOGi/lib/python3.10/site-packages (0.5.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import cv2
import imutils 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Attempt 1

# %%
image = cv2.imread("/Users/ejm-b/code/edwardmb12/YOGi/white_shapes.webp")

gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
thresh_image = cv2.threshold(gray_image, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

contours = cv2.findContours(thresh_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
contours = contours[0] if len(contours) == 2 else contours[1]

for i in contours:
    x,y,w,h = cv2.boundingRect(i)
    cv2.rectangle(image, (x, y), (x + w, y + h), (255,0,0), 4)
    
# result = cv2.imshow('Bounding Box', image)

# %% [markdown]
# ## Attempt 2

# %%
im = cv2.imread("/Users/ejm-b/code/edwardmb12/YOGi/Yoga_images_test/Downward-Facing-Dog.jpeg")

gray=cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)

contours, hierarchy = cv2.findContours(gray,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

idx =0 
for cnt in contours:
    idx += 1
    x,y,w,h = cv2.boundingRect(cnt)
    roi=im[y:y+h,x:x+w]
    cv2.imwrite(str(idx) + '.jpg', roi)
    #cv2.rectangle(im,(x,y),(x+w,y+h),(200,0,0),2)
    
cv2.imshow('img',im)
cv2.waitKey(0)

# %% [markdown]
# ## Attempt 3

# %%
# Out:
# (1000, 1500)

# %%
# import required libraries
import cv2

# Reading the Image
image = cv2.imread("/Users/ejm-b/code/edwardmb12/YOGi/Yoga_images_test/WarriorOne.jpeg", 0)

# image.shape

# initialize the HOG descriptor
hog = cv2.HOGDescriptor()
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())

# detect humans in input image
(humans, _) = hog.detectMultiScale(
    image, 
    winStride=(4, 4),
    padding=(256, 256), 
    scale=1.3,
    useMeanshiftGrouping=True
)

# getting no. of human detected
print('Human Detected : ', len(humans))

# loop over all detected humans
for (x, y, w, h) in humans:
    pad_w, pad_h = int(0.15 * w), int(0.01 * h)
    image = cv2.rectangle(image, (x + pad_w, y + pad_h), (x + w - pad_w, y + h - pad_h), (0, 255, 0), 2)

plt.imshow(image, cmap='gray')
    
# display the output image
# cv2.imshow("Image", image)
# cv2.waitKey(5)
# Out:
# Human Detected :  0

# %%
humans
# Out:
# ()

# %%
plt.imshow(image)

# %% [markdown]
# ## Attempt 4

# %%
image = cv2.imread("/Users/ejm-b/code/edwardmb12/YOGi/Yoga_images_test/WarriorOne.jpeg")

image = imutils.resize(image, 
                       width=min(500, image.shape[1]))

hog = cv2.HOGDescriptor()  
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())

(humans, _) = hog.detectMultiScale(image,  
                                    winStride=(5, 5), 
                                    padding=(3, 3), 
                                    scale=1.21)

for (x, y, w, h) in humans: 
    cv2.rectangle(image, (x, y),  
                  (x + w, y + h),  
                  (0, 0, 255), 2)
        
cv2.imshow("Image", image) 
cv2.waitKey(0) 
   
cv2.destroyAllWindows()

# %% [markdown]
# ## Attempt 5

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
file_path = "/Users/ejm-b/code/edwardmb12/YOGi/Yoga_images_test/"
file_list = os.listdir(file_path)
file_list
